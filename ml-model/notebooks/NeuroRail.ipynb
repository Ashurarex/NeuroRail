# %%
model = YOLO(r"C:\Users\Raghavendra\Desktop\NeuroRail v1\ml-model\models\final_model.pt")

cap = cv2.VideoCapture(r"C:\Users\Raghavendra\Desktop\NeuroRail v1\ml-model\videos\demo.mp4")

# %%
import os
from ultralytics import YOLO
import cv2

# Move from notebooks → ml-model
BASE_DIR = os.path.dirname(os.getcwd())

model_path = os.path.join(BASE_DIR, "models", "final_model.pt")
video_path = os.path.join(BASE_DIR, "videos", "demo.mp4")

print("Model path:", model_path)
print("Video path:", video_path)

model = YOLO(model_path)
cap = cv2.VideoCapture(video_path)
# Out:
# Model path: c:\Users\Raghavendra\Desktop\NeuroRail v1\ml-model\models\final_model.pt
# Video path: c:\Users\Raghavendra\Desktop\NeuroRail v1\ml-model\videos\demo.mp4

# %%
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run detection
    results = model(frame, conf=0.5)

    # Draw boxes
    annotated = results[0].plot()

    # Show output
    cv2.imshow("NeuroRail Demo", annotated)

    # Press Q to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import os
from ultralytics import YOLO
import cv2

# Fix for Jupyter
BASE_DIR = os.path.dirname(os.getcwd())

model_path = os.path.join(BASE_DIR, "models", "final_model.pt")
video_path = os.path.join(BASE_DIR, "videos", "demo.mp4")

model = YOLO(model_path)
cap = cv2.VideoCapture(video_path)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame, conf=0.5)
    annotated = results[0].plot()

    cv2.imshow("NeuroRail Demo", annotated)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import os
from ultralytics import YOLO
import cv2

BASE_DIR = os.path.dirname(os.getcwd())

model_path = os.path.join(BASE_DIR, "models", "final_model.pt")
video_path = os.path.join(BASE_DIR, "videos", "demo.mp4")

print(model_path)
print(video_path)

model = YOLO(model_path)
cap = cv2.VideoCapture(video_path)
# Out:
# c:\Users\Raghavendra\Desktop\NeuroRail v1\ml-model\models\final_model.pt
# c:\Users\Raghavendra\Desktop\NeuroRail v1\ml-model\videos\demo.mp4

# %%
import os
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt

BASE_DIR = os.path.dirname(os.getcwd())

model_path = os.path.join(BASE_DIR, "models", "final_model.pt")
video_path = os.path.join(BASE_DIR, "videos", "demo.mp4")

model = YOLO(model_path)

cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()
cap.release()

# IMPORTANT: pass frame
results = model(frame, conf=0.5)

annotated = results[0].plot()

plt.imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# WARNING 'source' is missing. Using 'source=C:\Users\Raghavendra\Desktop\NeuroRail v1\backend\venv\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\Raghavendra\Desktop\NeuroRail v1\backend\venv\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 93.6ms
# image 2/2 C:\Users\Raghavendra\Desktop\NeuroRail v1\backend\venv\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 73.3ms
# Speed: 2.2ms preprocess, 83.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)

# %%
import os
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt

# Path fix
BASE_DIR = os.path.dirname(os.getcwd())

model_path = os.path.join(BASE_DIR, "models", "final_model.pt")
video_path = os.path.join(BASE_DIR, "videos", "demo.mp4")

print("Model:", model_path)
print("Video:", video_path)

# Load model
model = YOLO(model_path)

# Read video frame
cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()
cap.release()

# 🔴 CRITICAL LINE (DO NOT CHANGE)
results = model(frame, conf=0.3)

# Draw boxes
annotated = results[0].plot()

# Show output
plt.imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# Model: c:\Users\Raghavendra\Desktop\NeuroRail v1\ml-model\models\final_model.pt
# Video: c:\Users\Raghavendra\Desktop\NeuroRail v1\ml-model\videos\demo.mp4
# WARNING 'source' is missing. Using 'source=C:\Users\Raghavendra\Desktop\NeuroRail v1\backend\venv\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\Raghavendra\Desktop\NeuroRail v1\backend\venv\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 100.1ms
# image 2/2 C:\Users\Raghavendra\Desktop\NeuroRail v1\backend\venv\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 80.8ms
# Speed: 1.6ms preprocess, 90.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)

# %%
print("Frame loaded:", ret)
print("Frame type:", type(frame))
# Out:
# Frame loaded: False
# Frame type: <class 'NoneType'>

# %%
import os

print(os.path.exists(video_path))
# Out:
# False

# %%
import cv2

video_path = r"C:\Users\Raghavendra\Desktop\NeuroRail v1\ml-model\videos\demo.mp4"

cap = cv2.VideoCapture(video_path)

print("Opened:", cap.isOpened())

ret, frame = cap.read()
print("Frame loaded:", ret)

cap.release()
# Out:
# Opened: False
# Frame loaded: False

# %%
import cv2

video_path = r"C:\Users\Raghavendra\Desktop\NeuroRail v1\ml-model\videos\demo.mp4"

cap = cv2.VideoCapture(video_path)

print("Opened:", cap.isOpened())

ret, frame = cap.read()
print("Frame loaded:", ret)

cap.release()
# Out:
# Opened: False
# Frame loaded: False
